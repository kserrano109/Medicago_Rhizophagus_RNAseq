# %%
library(dplyr)
library(Seurat)
library(patchwork)
library(here)
library(SeuratObject)
library(Matrix)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching SeuratObject
#
# here() starts at /global/u1/m/margot

# %%
#all medicago datasets:

data.dir1 <-"/global/cfs/projectdirs/m342/plant-microbe_shared/Chromium_outs/Chromium_medicago_outs/MBBC001A_ensembl/outs/filtered_feature_bc_matrix" #med28_1
data.dir2 <-"/global/cfs/projectdirs/m342/plant-microbe_shared/Chromium_outs/Chromium_medicago_outs/output_Mt_with_AMF_MBBC022B/outs/filtered_feature_bc_matrix" #med28_2
data.dir3 <-"/global/cfs/projectdirs/m342/plant-microbe_shared/Chromium_outs/Chromium_medicago_outs/output_Mt_no_AMF_MBBC022A/outs/filtered_feature_bc_matrix" #med28_2ctrl
data.dir4 <-"/global/cfs/projectdirs/m342/plant-microbe_shared/Chromium_outs/Chromium_medicago_outs/MBBC003A_ensembl/filtered_feature_bc_matrix" #med38
data.dir5 <-"/global/cfs/projectdirs/m342/plant-microbe_shared/Chromium_outs/Chromium_medicago_outs/MBBC003B_ensembl/filtered_feature_bc_matrix" #med38ctrl
data.dir6 <-"/global/cfs/projectdirs/m342/plant-microbe_shared/Chromium_outs/Chromium_medicago_outs/MBBC002A_ensembl/outs/filtered_feature_bc_matrix" #med21
data.dir7 <-"/global/cfs/projectdirs/m342/plant-microbe_shared/Chromium_outs/Chromium_medicago_outs/MBBC002B_ensembl/filtered_feature_bc_matrix" #med21ctrl

med28_1<-Read10X(
  data.dir1,
  gene.column = 2,
  cell.column = 1,
  unique.features = TRUE,
  strip.suffix = FALSE
)

med28_2<-Read10X(
  data.dir2,
  gene.column = 2,
  cell.column = 1,
  unique.features = TRUE,
  strip.suffix = FALSE
)

med28_2ctrl<-Read10X(
  data.dir3,
  gene.column = 2,
  cell.column = 1,
  unique.features = TRUE,
  strip.suffix = FALSE
)

med38<-Read10X(
  data.dir4,
  gene.column = 2,
  cell.column = 1,
  unique.features = TRUE,
  strip.suffix = FALSE
)

med38ctrl<-Read10X(
  data.dir5,
  gene.column = 2,
  cell.column = 1,
  unique.features = TRUE,
  strip.suffix = FALSE
)

med21<-Read10X(
  data.dir6,
  gene.column = 2,
  cell.column = 1,
  unique.features = TRUE,
  strip.suffix = FALSE
)

med21ctrl<-Read10X(
  data.dir7,
  gene.column = 2,
  cell.column = 1,
  unique.features = TRUE,
  strip.suffix = FALSE
)

med28_1<- CreateSeuratObject(counts = med28_1, project="med28_1")
VlnPlot(med28_1, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)
med28_1 <- subset(med28_1,nFeature_RNA > 300)
VlnPlot(med28_1, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)

med28_2 <- CreateSeuratObject(counts = med28_2, project="med28_2")
VlnPlot(med28_2, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)
med28_2 <- subset(med28_2, nFeature_RNA > 200)
VlnPlot(med28_2, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)

med28_2ctrl <- CreateSeuratObject(counts = med28_2ctrl, project="med28_2ctrl")
VlnPlot(med28_2ctrl, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)
med28_2ctrl <- subset(med28_2ctrl, nFeature_RNA > 200)
VlnPlot(med28_2ctrl, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)

med38 <- CreateSeuratObject(counts = med38, project="med38")
VlnPlot(med38, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)
med38 <- subset(med38, nFeature_RNA > 300)
VlnPlot(med38, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)

med38ctrl <- CreateSeuratObject(counts = med38ctrl, project="med38ctrl")
VlnPlot(med38ctrl, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)
med38ctrl <- subset(med38ctrl, nFeature_RNA > 300)
VlnPlot(med38ctrl, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)

med21 <- CreateSeuratObject(counts = med21, project="med21")
VlnPlot(med21, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)
med21 <- subset(med21, nFeature_RNA > 300)
VlnPlot(med21, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)

med21ctrl <- CreateSeuratObject(counts = med21ctrl, project="med21ctrl")
VlnPlot(med21ctrl, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)
med21ctrl <- subset(med21ctrl, nFeature_RNA > 300)
VlnPlot(med21ctrl, features = c("nFeature_RNA", "nCount_RNA"), ncol = 2, pt.size = .05)

# %%
med28_1 <- SCTransform(med28_1, verbose = TRUE)
med28_1 <- RunPCA(med28_1, npcs = 30, verbose = FALSE)
med28_1 <- RunUMAP(med28_1, reduction = "pca", dims = 1:30)
med28_1 <- FindNeighbors(med28_1, reduction = "pca", dims = 1:30)
med28_1 <- FindClusters(med28_1, resolution = 0.5)

med28_2 <- SCTransform(med28_2, verbose = TRUE)
med28_2 <- RunPCA(med28_2, npcs = 30, verbose = FALSE)
med28_2 <- RunUMAP(med28_2, reduction = "pca", dims = 1:30)
med28_2 <- FindNeighbors(med28_2, reduction = "pca", dims = 1:30)
med28_2 <- FindClusters(med28_2, resolution = 0.5)

med38 <- SCTransform(med38, verbose = TRUE)
med38 <- RunPCA(med38, npcs = 30, verbose = FALSE)
med38 <- RunUMAP(med38, reduction = "pca", dims = 1:30)
med38  <- FindNeighbors(med38, reduction = "pca", dims = 1:30)
med38  <- FindClusters(med38, resolution = 0.5)

med38ctrl <- SCTransform(med38ctrl, verbose = TRUE)
med38ctrl <- RunPCA(med38ctrl, npcs = 30, verbose = FALSE)
med38ctrl <- RunUMAP(med38ctrl, reduction = "pca", dims = 1:30)
med38ctrl <- FindNeighbors(med38ctrl, reduction = "pca", dims = 1:30)
med38ctrl <- FindClusters(med38ctrl, resolution = 0.5)

med28_2ctrl <- SCTransform(med28_2ctrl, verbose = TRUE)
med28_2ctrl <- RunPCA(med28_2ctrl, npcs = 30, verbose = FALSE)
med28_2ctrl <- RunUMAP(med28_2ctrl, reduction = "pca", dims = 1:30)
med28_2ctrl <- FindNeighbors(med28_2ctrl, reduction = "pca", dims = 1:30)
med28_2ctrl <- FindClusters(med28_2ctrl, resolution = 0.5)

med21 <- SCTransform(med21, verbose = TRUE)
med21 <- RunPCA(med21, npcs = 30, verbose = FALSE)
med21 <- RunUMAP(med21, reduction = "pca", dims = 1:30)
med21  <- FindNeighbors(med21, reduction = "pca", dims = 1:30)
med21  <- FindClusters(med21, resolution = 0.5)

med21ctrl <- SCTransform(med21ctrl, verbose = TRUE)
med21ctrl <- RunPCA(med21ctrl, npcs = 30, verbose = FALSE)
med21ctrl <- RunUMAP(med21ctrl, reduction = "pca", dims = 1:30)
med21ctrl  <- FindNeighbors(med21ctrl, reduction = "pca", dims = 1:30)
med21ctrl  <- FindClusters(med21ctrl, resolution = 0.5)

# %%
med.list<-c(med28_1, med28_2, med28_2ctrl, med38, med38ctrl, med21, med21ctrl)

med.features <- SelectIntegrationFeatures(object.list = med.list, nfeatures=3000)

all.genes <- lapply(med.list, row.names) %>% Reduce(c, .) %>% unique()

med.list <-PrepSCTIntegration(med.list,assay = NULL,anchor.features=med.features,sct.clip.range = NULL,verbose = TRUE)

med.anchors <- FindIntegrationAnchors(object.list = med.list, normalization.method = "SCT", anchor.features = med.features)

med <- IntegrateData(anchorset = med.anchors, normalization.method = "SCT", verbose = TRUE, features.to.integrate = all.genes)

# %%
DefaultAssay(med)<-'integrated'
med <- RunPCA(med, npcs = 30, verbose = FALSE)
med <- RunUMAP(med, reduction = "pca", dims = 1:30)
med <- FindNeighbors(med, reduction = "pca", dims = 1:30)
med <- FindClusters(med, resolution = 0.5)

# %%
DefaultAssay(med)<-'SCT'
#visualize integrated dataset by cell type and by dataset

#name clusters:
med <- RenameIdents(object = med,
"0" = "Cortex 1",
"1" = "Cortex 2",
"2" = "Stele 1",
"3" = "Cortex 3",
"4" = "Cortex 4",
"5" = "Cortex 5", 
"6" = "Epidermis", 
"7" = "Vascular Pericycle 1", 
"8" = "Cortex 6", 
"9" = "Cortex 7",
"10" = "Endodermis", 
"11" = "LRP 1", 
"12" = "Vascular Pericycle 2",
"13" = "Cortex 8",
"14" = "LRP 2", 
"15" = "unknown", 
"16" = "Phloem",
"17" = "Stele 2",
"18" = "Stele 3")   

cell_type<-Idents(object = med)
med<-AddMetaData(object = med, metadata = cell_type, col.name = "cell_type")

colors = c("#FF9999",
"#FF6666",
"#FFCC66",
"#FF6699",
"#CC99FF",
"#CC6699",
"#99CCFF",
"#ff9933",
"#FF99FF",
"#FF99CC",
"#99CCCC",
"#66CC99",
"#CC6600",
"#FFCCCC",
"#339966",
"#CCCCCC",
"#CC9999",
"#996666",
"#FFFF99")

#Supp Figure 3
DimPlot(med, reduction = "umap", group.by = "cell_type", cols = colors, label = FALSE, pt.size = 0.5)
DimPlot(med, reduction = "umap", group.by = "orig.ident", label = FALSE, pt.size = 0.5)
